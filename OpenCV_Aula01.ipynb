# %%
# Marcos Vinícius
# Para carregar uma imagem vinda da internet (link) podemos usar o 'wget' do linux:
# !wget -O 'imagem.jpg' 'https://thumbs.dreamstime.com/b/paisagem-bonita-da-natureza-no-c%C3%A9u-azul-148635957.jpg'
# Out:
# --2022-09-23 18:36:00--  https://thumbs.dreamstime.com/b/paisagem-bonita-da-natureza-no-c%C3%A9u-azul-148635957.jpg
# Resolving thumbs.dreamstime.com (thumbs.dreamstime.com)... 192.229.163.122
# Connecting to thumbs.dreamstime.com (thumbs.dreamstime.com)|192.229.163.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67762 (66K) [image/jpeg]
# Saving to: ‘imagem.jpg’
#
# imagem.jpg          100%[===================>]  66.17K  --.-KB/s    in 0.01s
#
# 2022-09-23 18:36:00 (4.88 MB/s) - ‘imagem.jpg’ saved [67762/67762]

# %%
import cv2
#A função cv2.imshow é incompatível com Colab, por isso temos que usar cv2_imshow:
from google.colab.patches import cv2_imshow

# %%
# Aqui decidimos não modificar a ordem dos pixels da imagem:
img = cv2.imread('imagem.jpg', cv2.IMREAD_UNCHANGED)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x625 at 0x7FB5EE758350>

# %%
# Exemplo de uso de conversão de cores. Convertendo uma imagem de BGR para escala de cinza:
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=800x625 at 0x7FB5EE6E6DD0>

# %%
# Exemplo de uso de conversão de cores. Convertendo uma imagem de BGR para escala de RGB:
imgBGR = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2_imshow(imgBGR)
# Out:
# <PIL.Image.Image image mode=RGB size=800x625 at 0x7FB5EE6F1790>

# %%
# Função de desenho: desenhando círculo:
cv2.circle(img, (130, 130), 85, (255,0,255), 45 )
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x625 at 0x7FB5EE6F1890>

# %%
img = cv2.imread('imagem.jpg', cv2.IMREAD_UNCHANGED)
print(img.shape)

cv2.rectangle(img, (128, 128), (163, 172), (255, 255, 0, 0), 10)
cv2_imshow(img)

cv2.imwrite("imamge.jpg", img)
# Out:
# (625, 800, 3)
# <PIL.Image.Image image mode=RGB size=800x625 at 0x7FB5EE700690>
# True

# %%
# Desfocando (Blur) em uma imagem grayscale usando filtro Guassiano (padrão): 
imBlur = cv2.blur(gray,(45,45))
cv2_imshow(imBlur)
# Out:
# <PIL.Image.Image image mode=L size=800x625 at 0x7FB5EE6E6C50>

# %% [markdown]
# Exercícios:
#
# 1. Carregue uma image a sua escolha;
# 2. Visualize a imagem;
# 3. Desenhe um objeto na imagem (círculo ou retângulo ou texto);
# 4. Mostre a imagem resultante;
# 5. Converta a imagem para escala de cinza;
# 6. Mostre a imagem resultante.

# %%
from google.colab.patches import cv2_imshow
import cv2

cap = cv2.VideoCapture('video.mp4')
while cap.isOpened():
    ret, image = cap.read()

    if not ret:
      break

    cv2_imshow(image) # Note cv2_imshow em vez de cv2.imshow

    cv2.waitKey(1) & 0xff

cv2.destroyAllWindows()
cap.release()
